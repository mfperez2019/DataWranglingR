# %%
import pandas as pd
import numpy as np
import re
from collections import Counter
from textblob import TextBlob
import nltk
nltk.download('wordnet')
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Mafer\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Mafer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
data = pd.read_csv("DWTS.csv",sep=',',encoding = "utf-8")

# %%
data.head()
# Out:
#                                                 text  favorited  \
# 0  RT @chloewetzel2: Why is sean still on @Dancin...      False
# 1  RT @BrettSVergara: Sean Spicer being told he w...      False
# 2  RT @BrettSVergara: Live footage of me hearing ...      False
# 3  RT @PromotingAlly: Ally was in the bottom 2. O...      False
# 4  RT @spoonmoonjune: The people vote for Spicer ...      False
#
#    favoriteCount replyToSN               created  truncated  replyToSID  \
# 0              0       NaN  2019-10-22T02:11:19Z      False         NaN
# 1              0       NaN  2019-10-22T02:11:18Z      False         NaN
# 2              0       NaN  2019-10-22T02:11:18Z      False         NaN
# 3              0       NaN  2019-10-22T02:11:16Z      False         NaN
# 4              0       NaN  2019-10-22T02:11:16Z      False         NaN
#
#                     id  replyToUID  \
# 0  1186465022496661505         NaN
# 1  1186465019753615360         NaN
# 2  1186465017811439617         NaN
# 3  1186465010266099713         NaN
# 4  1186465009267806211         NaN
#
#                                         statusSource     screenName  \
# 0  <a href="http://twitter.com/download/iphone" r...        haddmad
# 1  <a href="http://twitter.com/download/iphone" r...       cmagda28
# 2  <a href="http://twitter.com/download/iphone" r...      NotKieth1
# 3  <a href="http://twitter.com/download/android" ...  ghostinbrooke
# 4  <a href="https://mobile.twitter.com" rel="nofo...     DiGarBlizz
#
#    retweetCount  isRetweet  retweeted  longitude  latitude
# 0            21       True      False        NaN       NaN
# 1            53       True      False        NaN       NaN
# 2            65       True      False        NaN       NaN
# 3             2       True      False        NaN       NaN
# 4             1       True      False        NaN       NaN

# %%
data[data['screenName']=='haddmad']
# Out:
#                                                  text  favorited  \
# 0   RT @chloewetzel2: Why is sean still on @Dancin...      False
# 25  RT @_In_Zayn_: Why is Sean Spicer still there?...      False
# 76  RT @BrettSVergara: Sean Spicer being told he w...      False
#
#     favoriteCount replyToSN               created  truncated  replyToSID  \
# 0               0       NaN  2019-10-22T02:11:19Z      False         NaN
# 25              0       NaN  2019-10-22T02:11:04Z      False         NaN
# 76              0       NaN  2019-10-22T02:10:31Z      False         NaN
#
#                      id  replyToUID  \
# 0   1186465022496661505         NaN
# 25  1186464958248378370         NaN
# 76  1186464823372111872         NaN
#
#                                          statusSource screenName  \
# 0   <a href="http://twitter.com/download/iphone" r...    haddmad
# 25  <a href="http://twitter.com/download/iphone" r...    haddmad
# 76  <a href="http://twitter.com/download/iphone" r...    haddmad
#
#     retweetCount  isRetweet  retweeted  longitude  latitude
# 0             21       True      False        NaN       NaN
# 25            16       True      False        NaN       NaN
# 76            53       True      False        NaN       NaN

# %%
polarity = []
subjectivity = []
dataX = data.head(500)

for tw in dataX['text']:
  tw = TextBlob(tw)
  ann = tw.sentiment
  polarity.append(ann[0])
  subjectivity.append(ann[1])

# %%
SentAnlycs = pd.DataFrame({'Tweet':dataX['text'],'Polarity':polarity,'Subjectivity':subjectivity})
SentAnlycs
# Out:
#      Polarity  Subjectivity                                              Tweet
# 0    0.000000      0.000000  RT @chloewetzel2: Why is sean still on @Dancin...
# 1    0.533333      0.633333  RT @BrettSVergara: Sean Spicer being told he w...
# 2    0.136364      0.500000  RT @BrettSVergara: Live footage of me hearing ...
# 3   -0.100000      0.000000  RT @PromotingAlly: Ally was in the bottom 2. O...
# 4    0.000000      0.000000  RT @spoonmoonjune: The people vote for Spicer ...
# 5    0.000000      0.000000  RT @DWTSInteract: Kel and Witney: Quickstep\n\...
# 6    0.000000      0.000000  RT @Allyj96: How has Sean Spicer not been elim...
# 7    0.125000      0.750000  RT @BrettSVergara: Alan’s even better at strip...
# 8    0.500000      0.500000  Oh my goodness. This bottom two broke my heart...
# 9   -0.800000      0.900000  The snot shot though. Hate to see it #DWTS htt...
# 10  -0.350000      0.400000  RT @usweekly: #DWTS included a ton of tears .....
# 11   0.025000      0.208333  #DWTS apparently did not learn anything from l...
# 12   0.136364      0.500000  RT @BrettSVergara: Live footage of me hearing ...
# 13   0.100000      0.400000  RT @vladsdwts: Never cast anyone tied to polit...
# 14   0.000000      0.000000  How is Spicer still there? How?I just don't un...
# 15   0.250000      0.250000  If Sean had any character, he would back out f...
# 16  -0.550000      0.900000  RT @karinavela_: #DWTS y’all did sailor DIRTY,...
# 17   0.625000      0.888889  RT @Iamkelmitchell: Just finished my quick-ste...
# 18  -0.333333      0.466667  RT @witloalanbama: the fact that ally was in t...
# 19   0.400000      0.366667  RT @divadejadiva1: i was really about to lose ...
# 20   0.000000      0.000000  @dinahkiwi @DancingABC I wish my favorites had...
# 21   0.000000      0.000000  RT @roobahemakkar: Dear republicans, you alrea...
# 22  -0.900000      1.000000  RT @LauraMoffett17: When you are outraged that...
# 23   0.450000      0.633333  We’ve enjoyed watching Sean on #DWTS as much a...
# 24   0.000000      0.066667  RT @dwtsjobros: fck this damn show. fck sean s...
# 25   0.000000      0.000000  RT @_In_Zayn_: Why is Sean Spicer still there?...
# 26   0.000000      0.000000    RT @Ginger_Zee: What planet are we on #dwts ???
# 27  -0.200000      0.600000               Seriously crying for Sailor rn #DWTS
# 28   0.500000      0.500000  RT @divadejadiva1: literally me when they were...
# 29  -1.000000      1.000000  @DancingABC That was a horrible ending for Say...
# ..        ...           ...                                                ...
# 470 -0.333333      0.666667   Damn, is it that serious being eliminated? #DWTS
# 471  0.200000      0.300000  RT @juaelz1: #DWTS  why is Sean Spicer still t...
# 472  0.285714      0.535714  RT @seanspicer: Thank you for all of the suppo...
# 473 -0.175000      0.566667  s*an never shoulda been on in the first place ...
# 474  0.250000      0.250000  Also, all the people here obnoxiously ridiculi...
# 475  0.000000      0.000000  RT @AllyBrookeOn: 💔 #DWTS #TeamTime2Shine http...
# 476  0.000000      0.000000  RT @tvgoldtweets: these two did not deserve bo...
# 477 -0.333333      0.466667  RT @witloalanbama: the fact that ally was in t...
# 478 -0.333333      1.000000  The Russians have hacked @DancingABC. It is ri...
# 479  0.000000      0.000000  RT @erinjeanine_: @Lauren_Alaina’s performance...
# 480  0.450000      0.700000  WOW after the judges basically rigged the vote...
# 481 -0.312500      0.600000  RT @DestructiveChem: @ComfortablySmug The lib ...
# 482 -0.087500      0.300000  i guess i just don’t understands who actually ...
# 483  0.533333      0.633333  RT @BrettSVergara: Sean Spicer being told he w...
# 484  0.533333      0.633333  RT @BrettSVergara: Sean Spicer being told he w...
# 485 -0.400000      0.400000  @realityblurred The fixes they implemented are...
# 486 -0.900000      1.000000  When you are outraged that Sailor went home an...
# 487  0.000000      0.000000  RT @dinallyAB1: HOW WERE SASHA AND ALLY IN THE...
# 488  0.262500      0.375000  RT @JasonMillerinDC: By the looks of Twitter, ...
# 489  0.000000      0.000000  RT @_In_Zayn_: Why is Sean Spicer still there?...
# 490  0.000000      0.100000  It looks like another bogus season on DWTS pol...
# 491  0.000000      0.000000                                              #DWTS
# 492  0.000000      0.000000  RT @DancingABC: #TeamSweetNSpicey dancing to Q...
# 493 -0.500000      1.000000              i would have saved sailor sorry #DWTS
# 494  0.000000      0.000000  RT @Allyj96: How has Sean Spicer not been elim...
# 495 -0.400000      0.600000  RT @curtisadamski: WHO THE FUCK IS VOTING FOR ...
# 496  0.136364      0.500000  RT @BrettSVergara: Live footage of me hearing ...
# 497  0.550000      0.650000  RT @seanspicer: I finished my dance on @Dancin...
# 498  0.000000      0.500000  RT @almostjingo: VOTING IS OPEN! Vote for @sea...
# 499  0.690000      1.000000  RT @Shelby1822: Wow. So proud of you @Lauren_A...
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Funcion que crea el corpus de un usuario determinado

# %%
def corpus_creator(user,data):
    df= data[data['screenName']==user]
    df['text_length'] = df.text.str.len()
    df[['text']] = df.text.str.lower()
    out = df[['text','screenName','created','text_length']]
    return out

# %%
corpus = corpus_creator('haddmad',data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
corpus
# Out:
#                                                  text screenName  \
# 0   rt @chloewetzel2: why is sean still on @dancin...    haddmad
# 25  rt @_in_zayn_: why is sean spicer still there?...    haddmad
# 76  rt @brettsvergara: sean spicer being told he w...    haddmad
#
#                  created  text_length
# 0   2019-10-22T02:11:19Z          140
# 25  2019-10-22T02:11:04Z           78
# 76  2019-10-22T02:10:31Z          139

# %% [markdown]
# ## función normalizadora de texto

# %%
def word_norm(text):
  text = text.str.lower()
  text = text.replace('.', '')
  text = text.replace(',', '')
  text = text.replace('!', '')
  text = text.replace(to_replace =r'!', value='',regex=True)
  text = text.replace('á', 'a')
  text = text.replace('é', 'e')
  text = text.replace('í', 'i')
  text = text.replace('ó', 'o')
  text = text.replace('ú', 'u')
  text = text.replace('?', '')
  text = text.replace('!', '')
  text = text.replace(to_replace =r'-', value='',regex=True)
  text = text.replace(')', '')
  text = text.replace('(', '')
  text = text.replace(':', '')
  text = text.replace('/', '')
  return(text)

# %%
corpus[['text']] = word_norm(corpus.text)

# %%
corpus
# Out:
#                                                  text screenName  \
# 0   rt @chloewetzel2: why is sean still on @dancin...    haddmad
# 25  rt @_in_zayn_: why is sean spicer still there?...    haddmad
# 76  rt @brettsvergara: sean spicer being told he w...    haddmad
#
#                  created  text_length
# 0   2019-10-22T02:11:19Z          140
# 25  2019-10-22T02:11:04Z           78
# 76  2019-10-22T02:10:31Z          139

# %% [markdown]
# ## Funcion que calcula la polaridad y subjetividad de un tweet

# %%
def sentiment_analysis(text):
    polarity = []
    subjectivity = []
    for tw in text:
        tw = TextBlob(tw)
        ann = tw.sentiment
        polarity.append(ann[0])
        subjectivity.append(ann[1])

    return polarity,subjectivity

# %%
corpus['Polarity'], corpus['Subjectivity']= sentiment_analysis(corpus.text)

# %%
pd.set_option('display.max_colwidth', -1)
corpus.iloc[2:3,0]
# Out:
# 76    rt @brettsvergara: sean spicer being told he was safe before hannah found out is honestly the most upset i’ve ever been at a tv show #dwts…
# Name: text, dtype: object

# %% [markdown]
# # Lemmatization

# %%
#Sentence to lemmatize
sentence = "Among their university electives, the UFM students are taking a data wrangling course."

word_list = nltk.word_tokenize(sentence)
print(word_list)
# Out:
# ['Among', 'their', 'university', 'electives', ',', 'the', 'UFM', 'students', 'are', 'taking', 'a', 'data', 'wrangling', 'course', '.']

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# Lemmatize list of words and join
lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
print(lemmatized_output)
# Out:
# Among their university elective , the UFM student are taking a data wrangling course .

# %% [markdown]
# # Laboratorio
#
# Utilizando la librería de twitteR de R,el API de developer de twitter, y las librerías de análisis de sentimiento de Python:
#
#     1. Generar una consulta de algún #hashtag, tema o usuario que sea de su interés.
#         a. Transformar la respuesta del API de twitter a un dataframe e importarlo a un csv.
#         b. Presentar el código de consulta al API de twitter en un Rmarkdown. Nota: no desplegar los Tokens de su cuenta.
#     2. Importar el dataframe generado en R a Python.
#     3. Utilizando expresiones regulares:
#         a. Crear una función normalizadora de texto que limpie los caracteres que pueden generar ruido en el string del tweet.
#         b. Generar una nueva columna llamada "Handler" que muestre el handle del usuario. ej: @Tepi
#         c. Generar una nueva columna llamada "Source" que muestre de donde se generó el tweet. ej: Iphone, Android, etc.
#     4. Generar un corpus del dataset original que contenga: Handler,screenName,retweetCount,Source.
#     5. Generar una función que lematize cada tweet y guardar el resultado en una nueva columna llamada "lem_text".
#     6. Generar una función calcule la polaridad y subjetividad de las columnas "text" y "lem_text".
#     7. Utilizando pandas, calcular la media de la polaridad y subjetividad de todos las columnas del inciso 6 del corpus. Comparar si la lematización afecta en el resultado.
#     8. ¿Qué puede decir del sentimiento del corpus con base a la agregación del inciso 7?
#     9. Responder:
#         a. ¿De dónde se originan la mayoría de tweets de su corpus?
#         b. ¿Cuál es el tweet más popular de su corpus?
#
#     Extra: Generar un wordcloud utilizando Python en el cual se despliegue las palabras más frecuentes de la columna "lem_text"
